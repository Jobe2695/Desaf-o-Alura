# %% [markdown]
# <a href="https://colab.research.google.com/github/Jobe2695/Desaf-o-Alura/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# En este primer análisis, debes calcular el ingreso total de cada tienda. Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos.

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
ventast1 = tienda['Precio'].sum()
ventast1
# Out:
# np.float64(1150880400.0)

# %%
ventast2 = tienda2['Precio'].sum()
ventast2
# Out:
# np.float64(1116343500.0)

# %%
ventast3 =tienda3['Precio'].sum()
ventast3
# Out:
# np.float64(1098019600.0)

# %%
ventast4 = tienda4['Precio'].sum()
ventast4
# Out:
# np.float64(1038375700.0)

# %%
ventasmax = max(ventast1,ventast2,ventast3,ventast4)
ventasmax
# Out:
# np.float64(1150880400.0)

# %%
tventas = [ventast1,ventast2,ventast3,ventast4]
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

for i, v in enumerate(tventas):
  if v == ventasmax:
    print(f'Las ventas máximas son {ventasmax} y corresponden a la {nombres_tiendas[i]}')
# Out:
# Las ventas máximas son 1150880400.0 y corresponden a la Tienda 1

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
popularest1 = tienda.groupby('Categoría del Producto').count().head().sort_values('Producto', ascending=False)
popularest1
# Out:
#                          Producto  Precio  Costo de envío  Fecha de Compra  \
# Categoría del Producto
# Electrónicos                  448     448             448              448
# Electrodomésticos             312     312             312              312
# Deportes y diversión          284     284             284              284
# Instrumentos musicales        182     182             182              182
# Artículos para el hogar       171     171             171              171
#
#                          Vendedor  Lugar de Compra  Calificación  \
# Categoría del Producto
# Electrónicos                  448              448           448
# Electrodomésticos             312              312           312
# Deportes y diversión          284              284           284
# Instrumentos musicales        182              182           182
# Artículos para el hogar       171              171           171
#
#                          Método de pago  Cantidad de cuotas  lat  lon
# ...

# %%
popularest2 = tienda2.groupby('Categoría del Producto').count().head().sort_values('Producto', ascending=False)
popularest2
# Out:
#                          Producto  Precio  Costo de envío  Fecha de Compra  \
# Categoría del Producto
# Electrónicos                  422     422             422              422
# Electrodomésticos             305     305             305              305
# Deportes y diversión          275     275             275              275
# Instrumentos musicales        224     224             224              224
# Artículos para el hogar       181     181             181              181
#
#                          Vendedor  Lugar de Compra  Calificación  \
# Categoría del Producto
# Electrónicos                  422              422           422
# Electrodomésticos             305              305           305
# Deportes y diversión          275              275           275
# Instrumentos musicales        224              224           224
# Artículos para el hogar       181              181           181
#
#                          Método de pago  Cantidad de cuotas  lat  lon
# ...

# %%
popularest3 = tienda3.groupby('Categoría del Producto').count().head().sort_values('Producto', ascending=False)
popularest3
# Out:
#                          Producto  Precio  Costo de envío  Fecha de Compra  \
# Categoría del Producto
# Electrónicos                  451     451             451              451
# Electrodomésticos             278     278             278              278
# Deportes y diversión          277     277             277              277
# Artículos para el hogar       177     177             177              177
# Instrumentos musicales        177     177             177              177
#
#                          Vendedor  Lugar de Compra  Calificación  \
# Categoría del Producto
# Electrónicos                  451              451           451
# Electrodomésticos             278              278           278
# Deportes y diversión          277              277           277
# Artículos para el hogar       177              177           177
# Instrumentos musicales        177              177           177
#
#                          Método de pago  Cantidad de cuotas  lat  lon
# ...

# %%
popularest4 = tienda4.groupby('Categoría del Producto').count().head().sort_values('Producto', ascending=False)
popularest4
# Out:
#                          Producto  Precio  Costo de envío  Fecha de Compra  \
# Categoría del Producto
# Electrónicos                  451     451             451              451
# Deportes y diversión          277     277             277              277
# Electrodomésticos             254     254             254              254
# Artículos para el hogar       201     201             201              201
# Instrumentos musicales        170     170             170              170
#
#                          Vendedor  Lugar de Compra  Calificación  \
# Categoría del Producto
# Electrónicos                  451              451           451
# Deportes y diversión          277              277           277
# Electrodomésticos             254              254           254
# Artículos para el hogar       201              201           201
# Instrumentos musicales        170              170           170
#
#                          Método de pago  Cantidad de cuotas  lat  lon
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
tienda.head(2)
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   8  4.60971 -74.08175
# 1  Tarjeta de crédito                   4  6.25184 -75.56359

# %%
tienda.describe()
# Out:
#              Precio  Costo de envío  Calificación  Cantidad de cuotas  \
# count  2.359000e+03     2359.000000   2359.000000         2359.000000
# mean   4.878679e+05    26018.609580      3.976685            2.943196
# std    6.146868e+05    32860.001783      1.415370            2.819897
# min    7.600000e+03        0.000000      1.000000            1.000000
# 25%    5.575000e+04     3100.000000      3.000000            1.000000
# 50%    2.353000e+05    12400.000000      5.000000            1.000000
# 75%    6.781000e+05    36000.000000      5.000000            4.000000
# max    2.977000e+06   160800.000000      5.000000           24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean      5.365283   -74.789417
# std       2.287445     1.217827
# min      -4.215280   -77.281110
# 25%       4.609710   -75.563590
# 50%       4.609710   -74.199040
# 75%       6.251840   -74.081750
# max      11.544440   -67.923900

# %%
pcalificacion1 = float(tienda['Calificación'].mean().round(2))
pcalificacion1
# Out:
# 3.98

# %%
pcalificacion2 = float(tienda2['Calificación'].mean().round(2))
pcalificacion2
# Out:
# 4.04

# %%
pcalificacion3 = float(tienda3['Calificación'].mean().round(2))
pcalificacion3
# Out:
# 4.05

# %%
pcalificacion4 = float(tienda4['Calificación'].mean().round(2))
pcalificacion4
# Out:
# 4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
def ventas_por_tienda(df, nombre_tienda):
    ventas = df["Producto"].value_counts()

    print(f"\nTienda: {nombre_tienda}")
    print("Productos más vendidos:")
    display(ventas.head(5))  # top 5

    print("\nProductos menos vendidos:")
    display(ventas.tail(5))

    # Visualización
    ventas.plot(kind="bar")
    plt.title(f"Ventas por producto – {nombre_tienda}")
    plt.ylabel("Cantidad vendida")
    plt.xlabel("Producto")
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
ventas_por_tienda(tienda, "Tienda 1")
# Out:
# Tienda: Tienda 1
# Productos más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %%
ventas_por_tienda(tienda2, "Tienda 2")
# Out:
# Tienda: Tienda 2
# Productos más vendidos:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %%
ventas_por_tienda(tienda3, "Tienda 3")
# Out:
# Tienda: Tienda 3
# Productos más vendidos:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
ventas_por_tienda(tienda4, "Tienda 4")
# Out:
# Tienda: Tienda 4
# Productos más vendidos:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# Productos menos vendidos:
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda
